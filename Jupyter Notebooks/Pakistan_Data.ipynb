# %%
import pandas as pd

df = pd.read_csv("surveydata/pakistan_data.csv")

pd.set_option('display.max_columns', 61)
pd.set_option('display.max_rows', 61)

# %%
df
# Out:
#      Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 0           201  I am a developer by profession      Yes  27.0         18
# 1           569  I am a developer by profession       No  32.0         22
# 2           634  I am a developer by profession      Yes  25.0         18
# 3           763  I am a developer by profession      Yes   NaN         15
# 4           830  I am a developer by profession      Yes  25.0         22
# ..          ...                             ...      ...   ...        ...
# 804       22462                             NaN      Yes  22.0         16
# 805       47832                             NaN      Yes   NaN        NaN
# 806       55211                             NaN      Yes   NaN         31
# 807       55815                             NaN      Yes   NaN         10
# 808       61983                             NaN      Yes   NaN         25
#
#     CompFreq  CompTotal  ConvertedComp   Country     CurrencyDesc  \
# 0        NaN        NaN            NaN  Pakistan  Pakistani rupee
# 1    Monthly   220000.0        17124.0  Pakistan  Pakistani rupee
# 2    Monthly     2500.0          192.0  Pakistan  Pakistani rupee
# 3        NaN        NaN            NaN  Pakistan              NaN
# 4        NaN        NaN            NaN  Pakistan  Pakistani rupee
# ..       ...        ...            ...       ...              ...
# 804      NaN        NaN            NaN  Pakistan              NaN
# 805      NaN        NaN            NaN  Pakistan              NaN
# 806      NaN        NaN            NaN  Pakistan              NaN
# 807      NaN        NaN            NaN  Pakistan              NaN
# 808      NaN        NaN            NaN  Pakistan              NaN
#
#     CurrencySymbol                             DatabaseDesireNextYear  \
# 0              PKR  Couchbase;Elasticsearch;Firebase;MongoDB;MySQL...
# 1              PKR                             Firebase;MongoDB;Redis
# 2              PKR                  Microsoft SQL Server;MySQL;SQLite
# 3              NaN                                                NaN
# 4              PKR                               Microsoft SQL Server
# ..             ...                                                ...
# 804            NaN                                      MongoDB;MySQL
# 805            NaN                                                NaN
# 806            NaN                                          Cassandra
# 807            NaN                                              MySQL
# 808            NaN                         Microsoft SQL Server;MySQL
#
#                     DatabaseWorkedWith  \
# 0         Couchbase;MongoDB;PostgreSQL
# 1                                  NaN
# 2    Microsoft SQL Server;MySQL;SQLite
# 3                Firebase;MySQL;SQLite
# 4                 Microsoft SQL Server
# ..                                 ...
# 804                      MongoDB;MySQL
# 805                                NaN
# 806                          Cassandra
# 807                              MySQL
# 808                                NaN
#
#                                                DevType  \
# 0    Developer, back-end;Developer, desktop or ente...
# 1           Developer, front-end;Developer, full-stack
# 2    Academic researcher;Developer, desktop or ente...
# 3                                                  NaN
# 4        Data scientist or machine learning specialist
# ..                                                 ...
# 804                                                NaN
# 805                                                NaN
# 806                                                NaN
# 807                             Database administrator
# 808                           Data or business analyst
#
#                                                EdLevel  \
# 0         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ..                                                 ...
# 804                                                NaN
# 805       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 806                 Professional degree (JD, MD, etc.)
# 807                                                NaN
# 808  Secondary school (e.g. American high school, G...
#
#                                             Employment        Ethnicity  \
# 0                                   Employed full-time      South Asian
# 1                                   Employed full-time      South Asian
# 2    Independent contractor, freelancer, or self-em...       East Asian
# 3                                              Student              NaN
# 4                                   Employed full-time      South Asian
# ..                                                 ...              ...
# 804                                            Student  Southeast Asian
# 805                                 Employed part-time              NaN
# 806                                            Student   Middle Eastern
# 807                                 Employed part-time              NaN
# 808                                 Employed full-time       East Asian
#
#     Gender                                         JobFactors  \
# 0      Man  Flex time or a flexible schedule;How widely us...
# 1      Man  Languages, frameworks, and other technologies ...
# 2      Man                   Flex time or a flexible schedule
# 3      Man  Languages, frameworks, and other technologies ...
# 4      Man  Industry that I’d be working in;Remote work op...
# ..     ...                                                ...
# 804    Man                                                NaN
# 805    NaN                                                NaN
# 806    Man                                                NaN
# 807    NaN                                                NaN
# 808    Man                                                NaN
#
#                                  JobSat  \
# 0                    Slightly satisfied
# 1                 Slightly dissatisfied
# 2    Neither satisfied nor dissatisfied
# 3                                   NaN
# 4    Neither satisfied nor dissatisfied
# ..                                  ...
# 804                                 NaN
# 805                                 NaN
# 806                                 NaN
# 807                                 NaN
# 808                                 NaN
#
#                                                JobSeek  \
# 0    I’m not actively looking, but I am open to new...
# 1                      I am actively looking for a job
# 2    I’m not actively looking, but I am open to new...
# 3                      I am actively looking for a job
# 4    I’m not actively looking, but I am open to new...
# ..                                                 ...
# 804                                                NaN
# 805                                                NaN
# 806                                                NaN
# 807                                                NaN
# 808                                                NaN
#
#                                 LanguageDesireNextYear  \
# 0    Dart;Go;HTML/CSS;Java;JavaScript;Python;Rust;T...
# 1                            JavaScript;SQL;TypeScript
# 2                                              C#;Java
# 3                                                    C
# 4                                         Python;Scala
# ..                                                 ...
# 804                           C#;JavaScript;Python;SQL
# 805                                                NaN
# 806                                           Assembly
# 807                                     C++;JavaScript
# 808                                      HTML/CSS;Java
#
#                                     LanguageWorkedWith  \
# 0    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 1                                  HTML/CSS;JavaScript
# 2                                              C#;Java
# 3            C;HTML/CSS;Java;JavaScript;PHP;Python;SQL
# 4                                             Python;R
# ..                                                 ...
# 804         C#;HTML/CSS;Java;JavaScript;PHP;Python;SQL
# 805                                                NaN
# 806                                           Assembly
# 807                                     C++;JavaScript
# 808                                                NaN
#
#                                 MiscTechDesireNextYear MiscTechWorkedWith  \
# 0    .NET Core;Flutter;Node.js;Pandas;React Native;...    Cordova;Node.js
# 1                                              Node.js                NaN
# 2                                                 .NET               .NET
# 3                                                  NaN            Node.js
# 4    Apache Spark;Hadoop;Keras;TensorFlow;Torch/PyT...   Keras;TensorFlow
# ..                                                 ...                ...
# 804                     .NET Core;Node.js;React Native            Node.js
# 805                                                NaN                NaN
# 806                                               .NET               .NET
# 807                                               .NET               .NET
# 808                                 .NET;Unreal Engine                NaN
#
#                           NEWCollabToolsDesireNextYear  \
# 0    Confluence;Jira;Github;Trello;Google Suite (Do...
# 1    Jira;Github;Slack;Trello;Google Suite (Docs, M...
# 2                                               Github
# 3                                                  NaN
# 4                                               Github
# ..                                                 ...
# 804                                             Github
# 805                                                NaN
# 806                     Google Suite (Docs, Meet, etc)
# 807                                 Facebook Workplace
# 808                                   Confluence;Slack
#
#                               NEWCollabToolsWorkedWith NEWDevOps  \
# 0    Confluence;Jira;Github;Gitlab;Trello;Google Su...        No
# 1    Jira;Github;Slack;Trello;Google Suite (Docs, M...       Yes
# 2                                               Github  Not sure
# 3                                               Github       NaN
# 4                                               Github        No
# ..                                                 ...       ...
# 804                                             Github       NaN
# 805                                                NaN       NaN
# 806                     Google Suite (Docs, Meet, etc)       NaN
# 807                                 Facebook Workplace       NaN
# 808                                                NaN       NaN
#
#             NEWDevOpsImpt           NEWEdImpt  \
# 0     Extremely important      Very important
# 1     Extremely important  Somewhat important
# 2    Not at all important                 NaN
# 3                     NaN                 NaN
# 4      Not very important  Somewhat important
# ..                    ...                 ...
# 804                   NaN                 NaN
# 805                   NaN    Fairly important
# 806                   NaN                 NaN
# 807                   NaN      Very important
# 808                   NaN      Very important
#
#                                             NEWJobHunt  \
# 0    Curious about other opportunities;Better compe...
# 1    Curious about other opportunities;Better compe...
# 2    Better compensation;Trouble with my direct man...
# 3                                         Just because
# 4    Having a bad day (or week or month) at work;Be...
# ..                                                 ...
# 804                                                NaN
# 805                                                NaN
# 806                                                NaN
# 807                                                NaN
# 808                                                NaN
#
#                                     NEWJobHuntResearch              NEWLearn  \
# 0    Read company media, such as employee blogs or ...      Every few months
# 1    Read company media, such as employee blogs or ...      Every few months
# 2    Directly asking current or past employees at t...  Once every few years
# 3                 Personal network - friends or family      Every few months
# 4    Read company media, such as employee blogs or ...      Every few months
# ..                                                 ...                   ...
# 804                                                NaN           Once a year
# 805                                                NaN                   NaN
# 806                                                NaN                   NaN
# 807                                                NaN      Every few months
# 808                                                NaN  Once every few years
#
#     NEWOffTopic                NEWOnboardGood NEWOtherComms  \
# 0            No                           Yes           Yes
# 1            No  Onboarding? What onboarding?            No
# 2           Yes  Onboarding? What onboarding?            No
# 3           NaN                           NaN            No
# 4            No  Onboarding? What onboarding?            No
# ..          ...                           ...           ...
# 804    Not sure                           NaN           NaN
# 805         NaN                           NaN           NaN
# 806         NaN                           NaN           NaN
# 807         NaN                           NaN           NaN
# 808         NaN                           NaN           NaN
#
#                                            NEWOvertime  \
# 0    Occasionally: 1-2 days per quarter but less th...
# 1                    Rarely: 1-2 days per year or less
# 2    Occasionally: 1-2 days per quarter but less th...
# 3                                                  NaN
# 4    Sometimes: 1-2 days per month but less than we...
# ..                                                 ...
# 804                                                NaN
# 805                                                NaN
# 806                                                NaN
# 807                                                NaN
# 808                                                NaN
#
#                                    NEWPurchaseResearch      NEWPurpleLink  \
# 0    Start a free trial;Ask developers I know/work ...  Hello, old friend
# 1    Ask developers I know/work with;Visit develope...            Annoyed
# 2                                   Start a free trial            Annoyed
# 3                                   Start a free trial  Hello, old friend
# 4                                                  NaN  Hello, old friend
# ..                                                 ...                ...
# 804  Start a free trial;Visit developer communities...        Indifferent
# 805                                                NaN                NaN
# 806                                 Start a free trial            Annoyed
# 807  Start a free trial;Ask developers I know/work ...             Amused
# 808                                 Start a free trial  Hello, old friend
#
#                                             NEWSOSites  \
# 0    Stack Overflow (public Q&A for anyone who code...
# 1    Stack Overflow (public Q&A for anyone who code...
# 2     Stack Overflow (public Q&A for anyone who codes)
# 3                Stack Overflow Jobs (for job seekers)
# 4     Stack Overflow (public Q&A for anyone who codes)
# ..                                                 ...
# 804  Stack Overflow (public Q&A for anyone who code...
# 805            I have never visited any of these sites
# 806            I have never visited any of these sites
# 807              Stack Overflow Jobs (for job seekers)
# 808              Stack Overflow Jobs (for job seekers)
#
#                                               NEWStuck    OpSys  \
# 0    Play games;Call a coworker or friend;Visit Sta...    MacOS
# 1    Call a coworker or friend;Visit Stack Overflow...    MacOS
# 2                                 Visit Stack Overflow  Windows
# 3                         Watch help / tutorial videos  Windows
# 4    Visit Stack Overflow;Watch help / tutorial vid...    MacOS
# ..                                                 ...      ...
# 804  Visit Stack Overflow;Watch help / tutorial videos  Windows
# 805                                                NaN  Windows
# 806                                                NaN  Windows
# 807  Meditate;Play games;Call a coworker or friend;...  Windows
# 808                               Visit Stack Overflow  Windows
#
#                                                OrgSize  \
# 0                                   20 to 99 employees
# 1                                 100 to 499 employees
# 2    Just me - I am a freelancer, sole proprietor, ...
# 3                                                  NaN
# 4                             10,000 or more employees
# ..                                                 ...
# 804                                                NaN
# 805                                                NaN
# 806                                                NaN
# 807                                                NaN
# 808                                                NaN
#
#                                 PlatformDesireNextYear  \
# 0    AWS;Docker;Google Cloud Platform;Kubernetes;Li...
# 1                                                MacOS
# 2                                              Windows
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 804                         Android;Heroku;iOS;Windows
# 805                                                NaN
# 806                              Google Cloud Platform
# 807                                      Android;Linux
# 808                              Google Cloud Platform
#
#                              PlatformWorkedWith  \
# 0    Android;Arduino;AWS;Docker;iOS;Linux;MacOS
# 1                                         MacOS
# 2                                       Windows
# 3                                       Android
# 4                                           NaN
# ..                                          ...
# 804                              Heroku;Windows
# 805                                         NaN
# 806                       Google Cloud Platform
# 807                               Android;Linux
# 808                                     Android
#
#                          PurchaseWhat                Sexuality SOAccount  \
# 0               I have some influence  Straight / Heterosexual       Yes
# 1    I have a great deal of influence  Straight / Heterosexual       Yes
# 2                                 NaN  Straight / Heterosexual       Yes
# 3                                 NaN                      NaN       NaN
# 4       I have little or no influence  Straight / Heterosexual       Yes
# ..                                ...                      ...       ...
# 804                               NaN  Straight / Heterosexual       Yes
# 805                               NaN                      NaN       NaN
# 806                               NaN                      NaN       NaN
# 807                               NaN                      NaN       NaN
# 808                               NaN                      NaN       NaN
#
#               SOComm                           SOPartFreq  \
# 0    Yes, definitely                Daily or almost daily
# 1      Yes, somewhat      A few times per month or weekly
# 2      Yes, somewhat      A few times per month or weekly
# 3                NaN                                  NaN
# 4    Yes, definitely  Less than once per month or monthly
# ..               ...                                  ...
# 804  Yes, definitely  Less than once per month or monthly
# 805              NaN                                  NaN
# 806              NaN                                  NaN
# 807              NaN                                  NaN
# 808              NaN                                  NaN
#
#                          SOVisitFreq                  SurveyEase  \
# 0             Multiple times per day                        Easy
# 1              Daily or almost daily  Neither easy nor difficult
# 2             Multiple times per day                        Easy
# 3                                NaN                        Easy
# 4             Multiple times per day  Neither easy nor difficult
# ..                               ...                         ...
# 804  A few times per month or weekly                        Easy
# 805                              NaN                         NaN
# 806                              NaN                        Easy
# 807                              NaN                        Easy
# 808                              NaN  Neither easy nor difficult
#
#               SurveyLength Trans  \
# 0    Appropriate in length    No
# 1    Appropriate in length    No
# 2                 Too long    No
# 3                Too short    No
# 4    Appropriate in length    No
# ..                     ...   ...
# 804  Appropriate in length    No
# 805                    NaN   NaN
# 806              Too short   Yes
# 807               Too long    No
# 808  Appropriate in length    No
#
#                                         UndergradMajor  \
# 0    Computer science, computer engineering, or sof...
# 1    Computer science, computer engineering, or sof...
# 2    Information systems, information technology, o...
# 3    Computer science, computer engineering, or sof...
# 4                            Mathematics or statistics
# ..                                                 ...
# 804  Computer science, computer engineering, or sof...
# 805  A natural science (such as biology, chemistry,...
# 806  Another engineering discipline (such as civil,...
# 807  Another engineering discipline (such as civil,...
# 808                                                NaN
#
#                      WebframeDesireNextYear  \
# 0    Angular;Django;Express;React.js;Spring
# 1            Express;jQuery;React.js;Vue.js
# 2                                   ASP.NET
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 804           ASP.NET Core;Express;React.js
# 805                                     NaN
# 806                                 Angular
# 807                                     NaN
# 808                            Django;Flask
#
#                            WebframeWorkedWith  \
# 0    Angular;Angular.js;Express;jQuery;Spring
# 1                                      jQuery
# 2                                     ASP.NET
# 3                                     Laravel
# 4                                         NaN
# ..                                        ...
# 804                            Express;jQuery
# 805                                       NaN
# 806                                   Angular
# 807                                   Express
# 808                                       NaN
#
#                                WelcomeChange  WorkWeekHrs         YearsCode  \
# 0    Just as welcome now as I felt last year         40.0                 9
# 1      A lot less welcome now than last year         40.0                 8
# 2    Just as welcome now as I felt last year         42.0                 6
# 3                                        NaN          NaN                14
# 4    Just as welcome now as I felt last year         40.0                 4
# ..                                       ...          ...               ...
# 804  Just as welcome now as I felt last year          NaN                 6
# 805                                      NaN          NaN               NaN
# 806                                      NaN          NaN                 6
# 807                                      NaN          NaN  Less than 1 year
# 808                                      NaN          NaN  Less than 1 year
#
#     YearsCodePro
# 0              4
# 1              6
# 2              3
# 3            NaN
# 4              2
# ..           ...
# 804          NaN
# 805          NaN
# 806          NaN
# 807            4
# 808            3
#
# [809 rows x 61 columns]
