# %%
import pandas as pd

df = pd.read_json("surveydata/pakistan_data.json")

pd.set_option("display.max_columns", 61)
pd.set_option("display.max_rows", 61)

# %%
df
# Out:
#                            MainBranch Hobbyist   Age Age1stCode CompFreq  \
# 201    I am a developer by profession      Yes  27.0         18     None
# 569    I am a developer by profession       No  32.0         22  Monthly
# 634    I am a developer by profession      Yes  25.0         18  Monthly
# 763    I am a developer by profession      Yes   NaN         15     None
# 830    I am a developer by profession      Yes  25.0         22     None
# ...                               ...      ...   ...        ...      ...
# 22462                            None      Yes  22.0         16     None
# 47832                            None      Yes   NaN       None     None
# 55211                            None      Yes   NaN         31     None
# 55815                            None      Yes   NaN         10     None
# 61983                            None      Yes   NaN         25     None
#
#        CompTotal  ConvertedComp   Country     CurrencyDesc CurrencySymbol  \
# ...
